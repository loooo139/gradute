# %%
import tushare as ts

# %%
ts.set_token('da065b64a5cded7f403520458aee7e0e3893b0a1d4b8e86edd24bfd7')

# %%
pro=ts.pro_api()
# Out:
# /home/spark/.local/lib/python3.6/site-packages/tushare/util/upass.py:28: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   return str(df.ix[0]['token'])

# %%
df=pro.stock_company()

# %%
listColumns=[ i for i in df.columns]

# %%
listColumns.append('main_business')
listColumns.append('business_scope')

# %%
df_1=pro.stock_company(exchange='SZSE',field='main_business,business_scope')

# %%
','.join(listColumns)
# Out:
# 'ts_code,exchange,chairman,manager,secretary,reg_capital,setup_date,province,city,website,email,employees,main_business,business_scope'

# %%
df_1
# Out:
#         ts_code exchange  ...                                              email employees
# 0     002927.SZ     SZSE  ...  changzheng@taiyong.net;yuhui@taiyong.net;hanhf...     922.0
# 1     300696.SZ     SZSE  ...  sec@cdald.com;chenmiao85@cdald.com;zqbwendy@cd...     393.0
# 2     002960.SZ     SZSE  ...                                zhengquan@jbufa.com    2135.0
# 3     300742.SZ     SZSE  ...                             yuebozqb@yuebooemt.com     666.0
# 4     300700.SZ     SZSE  ...                                    diat@dialine.cn     895.0
# ...         ...      ...  ...                                                ...       ...
# 2221  300166.SZ     SZSE  ...                               investor@bonc.com.cn    6966.0
# 2222  002840.SZ     SZSE  ...                  lysn600@163.com;zjwyh2017@126.com    2141.0
# 2223  002853.SZ     SZSE  ...                webmaster@pianor.com;DMB@pianor.com    2251.0
# ...

# %%
df
# Out:
#         ts_code exchange  ...                                              email employees
# 0     603458.SH      SSE  ...              huanggj@gzjtsjy.com;yuhai@gzjtsjy.com      2943
# 1     603823.SH      SSE  ...                  wdm@lilygroup.cn;wzy@lilygroup.cn      1564
# 2     688010.SH      SSE  ...                            zhengquan01@forecam.com      1525
# 3     603203.SH      SSE  ...                       quickchina@quickchina.com.cn       700
# 4     603139.SH      SSE  ...                                     irsxkh@163.com       874
# ...         ...      ...  ...                                                ...       ...
# 1557  603816.SH      SSE  ...                            securities@kukahome.com     13021
# 1558  603300.SH      SSE  ...    lzl@zjhuatie.cn;zsx@zjhuatie.cn;zxm@zjhuatie.cn       227
# 1559  601226.SH      SSE  ...                                     hhi@hhi.com.cn      2572
# ...
